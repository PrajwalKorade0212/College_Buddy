# %%
import numpy as np
import nltk
import json
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import pickle
import random

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\korad\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\korad\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
intents = json.loads(open('intents.json').read())
words = []
classes = []
documents = []
ignore_letters = ['?', '!', '.',',']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize (pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
lemmatizer = WordNetLemmatizer()
words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))
classes = sorted(set(classes))

# %%
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# %%
import numpy as np

training = []
output_empty = [0] * len(classes)
for document in documents:
    bag = []
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
        
    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append([bag, output_row])
    
random.shuffle(training)
training = np.array(training, dtype=object)
word_patterns
# Out:
# ['who', 'is', 'the', 'hod']

# %%
train_x = list(training[:, 0])
train_y = list(training[:, 1])

# %%
model = Sequential()
model.add(Dense(128, input_shape = (len(train_x[0]),),activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'selu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation = 'softmax'))

sgd = SGD(lr = 0.01, decay = 1e-6, momentum = 0.9, nesterov = True)
model.compile(loss = 'categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'])

history = model.fit(np.array(train_x), np.array(train_y), epochs = 200, batch_size = 5, verbose =2)
model.save('chatbot_model.h5', history)
# Out:
# Epoch 1/200
# C:\Users\korad\anaconda3\envs\tensorflow_2\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 84/84 - 1s - loss: 3.5910 - accuracy: 0.0767 - 859ms/epoch - 10ms/step
# Epoch 2/200
# 84/84 - 0s - loss: 3.0905 - accuracy: 0.2326 - 170ms/epoch - 2ms/step
# Epoch 3/200
# 84/84 - 0s - loss: 2.5609 - accuracy: 0.3165 - 153ms/epoch - 2ms/step
# Epoch 4/200
# 84/84 - 0s - loss: 2.1463 - accuracy: 0.4221 - 142ms/epoch - 2ms/step
# Epoch 5/200
# 84/84 - 0s - loss: 1.7321 - accuracy: 0.5324 - 141ms/epoch - 2ms/step
# Epoch 6/200
# 84/84 - 0s - loss: 1.5171 - accuracy: 0.5995 - 136ms/epoch - 2ms/step
# Epoch 7/200
# 84/84 - 0s - loss: 1.3431 - accuracy: 0.6211 - 135ms/epoch - 2ms/step
# Epoch 8/200
# 84/84 - 0s - loss: 1.0971 - accuracy: 0.6787 - 129ms/epoch - 2ms/step
# Epoch 9/200
# 84/84 - 0s - loss: 0.9619 - accuracy: 0.7338 - 129ms/epoch - 2ms/step
# Epoch 10/200
# 84/84 - 0s - loss: 0.7782 - accuracy: 0.7818 - 123ms/epoch - 1ms/step
# Epoch 11/200
# 84/84 - 0s - loss: 0.7391 - accuracy: 0.7914 - 125ms/epoch - 1ms/step
# Epoch 12/200
# 84/84 - 0s - loss: 0.7228 - accuracy: 0.7794 - 123ms/epoch - 1ms/step
# Epoch 13/200
# 84/84 - 0s - loss: 0.6144 - accuracy: 0.8441 - 120ms/epoch - 1ms/step
# Epoch 14/200
# 84/84 - 0s - loss: 0.5696 - accuracy: 0.8417 - 121ms/epoch - 1ms/step
# Epoch 15/200
# 84/84 - 0s - loss: 0.5088 - accuracy: 0.8657 - 121ms/epoch - 1ms/step
# Epoch 16/200
# 84/84 - 0s - loss: 0.4725 - accuracy: 0.8585 - 121ms/epoch - 1ms/step
# Epoch 17/200
# 84/84 - 0s - loss: 0.4489 - accuracy: 0.8729 - 121ms/epoch - 1ms/step
# Epoch 18/200
# 84/84 - 0s - loss: 0.4069 - accuracy: 0.8729 - 121ms/epoch - 1ms/step
# Epoch 19/200
# 84/84 - 0s - loss: 0.3663 - accuracy: 0.9017 - 124ms/epoch - 1ms/step
# Epoch 20/200
# 84/84 - 0s - loss: 0.2891 - accuracy: 0.9113 - 121ms/epoch - 1ms/step
# Epoch 21/200
# 84/84 - 0s - loss: 0.3167 - accuracy: 0.9089 - 120ms/epoch - 1ms/step
# Epoch 22/200
# 84/84 - 0s - loss: 0.2790 - accuracy: 0.9209 - 120ms/epoch - 1ms/step
# Epoch 23/200
# 84/84 - 0s - loss: 0.2951 - accuracy: 0.9185 - 121ms/epoch - 1ms/step
# Epoch 24/200
# 84/84 - 0s - loss: 0.3278 - accuracy: 0.9017 - 121ms/epoch - 1ms/step
# Epoch 25/200
# 84/84 - 0s - loss: 0.2882 - accuracy: 0.9065 - 120ms/epoch - 1ms/step
# Epoch 26/200
# 84/84 - 0s - loss: 0.2796 - accuracy: 0.9257 - 120ms/epoch - 1ms/step
# Epoch 27/200
# 84/84 - 0s - loss: 0.2736 - accuracy: 0.9161 - 120ms/epoch - 1ms/step
# Epoch 28/200
# 84/84 - 0s - loss: 0.2405 - accuracy: 0.9257 - 120ms/epoch - 1ms/step
# Epoch 29/200
# 84/84 - 0s - loss: 0.2396 - accuracy: 0.9185 - 123ms/epoch - 1ms/step
# Epoch 30/200
# 84/84 - 0s - loss: 0.1974 - accuracy: 0.9400 - 141ms/epoch - 2ms/step
# Epoch 31/200
# 84/84 - 0s - loss: 0.2196 - accuracy: 0.9257 - 141ms/epoch - 2ms/step
# Epoch 32/200
# 84/84 - 0s - loss: 0.2176 - accuracy: 0.9353 - 123ms/epoch - 1ms/step
# Epoch 33/200
# 84/84 - 0s - loss: 0.2326 - accuracy: 0.9257 - 120ms/epoch - 1ms/step
# Epoch 34/200
# 84/84 - 0s - loss: 0.2355 - accuracy: 0.9209 - 119ms/epoch - 1ms/step
# Epoch 35/200
# 84/84 - 0s - loss: 0.1703 - accuracy: 0.9544 - 119ms/epoch - 1ms/step
# Epoch 36/200
# 84/84 - 0s - loss: 0.1492 - accuracy: 0.9496 - 119ms/epoch - 1ms/step
# Epoch 37/200
# 84/84 - 0s - loss: 0.1457 - accuracy: 0.9664 - 120ms/epoch - 1ms/step
# Epoch 38/200
# 84/84 - 0s - loss: 0.1321 - accuracy: 0.9664 - 119ms/epoch - 1ms/step
# Epoch 39/200
# 84/84 - 0s - loss: 0.1344 - accuracy: 0.9544 - 119ms/epoch - 1ms/step
# Epoch 40/200
# 84/84 - 0s - loss: 0.1595 - accuracy: 0.9496 - 119ms/epoch - 1ms/step
# Epoch 41/200
# 84/84 - 0s - loss: 0.1513 - accuracy: 0.9520 - 119ms/epoch - 1ms/step
# Epoch 42/200
# 84/84 - 0s - loss: 0.1572 - accuracy: 0.9496 - 119ms/epoch - 1ms/step
# Epoch 43/200
# 84/84 - 0s - loss: 0.1644 - accuracy: 0.9472 - 119ms/epoch - 1ms/step
# Epoch 44/200
# 84/84 - 0s - loss: 0.1381 - accuracy: 0.9568 - 118ms/epoch - 1ms/step
# Epoch 45/200
# 84/84 - 0s - loss: 0.1400 - accuracy: 0.9616 - 113ms/epoch - 1ms/step
# Epoch 46/200
# 84/84 - 0s - loss: 0.1639 - accuracy: 0.9568 - 107ms/epoch - 1ms/step
# Epoch 47/200
# 84/84 - 0s - loss: 0.1559 - accuracy: 0.9520 - 101ms/epoch - 1ms/step
# Epoch 48/200
# 84/84 - 0s - loss: 0.1679 - accuracy: 0.9448 - 98ms/epoch - 1ms/step
# Epoch 49/200
# 84/84 - 0s - loss: 0.1376 - accuracy: 0.9664 - 91ms/epoch - 1ms/step
# Epoch 50/200
# 84/84 - 0s - loss: 0.1398 - accuracy: 0.9616 - 87ms/epoch - 1ms/step
# Epoch 51/200
# 84/84 - 0s - loss: 0.1868 - accuracy: 0.9329 - 85ms/epoch - 1ms/step
# Epoch 52/200
# 84/84 - 0s - loss: 0.1309 - accuracy: 0.9592 - 83ms/epoch - 982us/step
# Epoch 53/200
# 84/84 - 0s - loss: 0.0981 - accuracy: 0.9640 - 98ms/epoch - 1ms/step
# Epoch 54/200
# 84/84 - 0s - loss: 0.1288 - accuracy: 0.9664 - 100ms/epoch - 1ms/step
# Epoch 55/200
# 84/84 - 0s - loss: 0.1259 - accuracy: 0.9616 - 100ms/epoch - 1ms/step
# Epoch 56/200
# 84/84 - 0s - loss: 0.1344 - accuracy: 0.9544 - 100ms/epoch - 1ms/step
# Epoch 57/200
# 84/84 - 0s - loss: 0.1065 - accuracy: 0.9688 - 100ms/epoch - 1ms/step
# Epoch 58/200
# 84/84 - 0s - loss: 0.1253 - accuracy: 0.9592 - 104ms/epoch - 1ms/step
# Epoch 59/200
# 84/84 - 0s - loss: 0.1026 - accuracy: 0.9688 - 100ms/epoch - 1ms/step
# Epoch 60/200
# 84/84 - 0s - loss: 0.0701 - accuracy: 0.9808 - 101ms/epoch - 1ms/step
# Epoch 61/200
# 84/84 - 0s - loss: 0.1580 - accuracy: 0.9472 - 100ms/epoch - 1ms/step
# Epoch 62/200
# 84/84 - 0s - loss: 0.0963 - accuracy: 0.9688 - 106ms/epoch - 1ms/step
# Epoch 63/200
# 84/84 - 0s - loss: 0.0991 - accuracy: 0.9688 - 100ms/epoch - 1ms/step
# Epoch 64/200
# 84/84 - 0s - loss: 0.0811 - accuracy: 0.9688 - 101ms/epoch - 1ms/step
# Epoch 65/200
# 84/84 - 0s - loss: 0.1083 - accuracy: 0.9664 - 101ms/epoch - 1ms/step
# Epoch 66/200
# 84/84 - 0s - loss: 0.1095 - accuracy: 0.9688 - 101ms/epoch - 1ms/step
# Epoch 67/200
# 84/84 - 0s - loss: 0.0970 - accuracy: 0.9664 - 100ms/epoch - 1ms/step
# Epoch 68/200
# 84/84 - 0s - loss: 0.1265 - accuracy: 0.9568 - 108ms/epoch - 1ms/step
# Epoch 69/200
# 84/84 - 0s - loss: 0.1106 - accuracy: 0.9664 - 101ms/epoch - 1ms/step
# Epoch 70/200
# 84/84 - 0s - loss: 0.1314 - accuracy: 0.9568 - 101ms/epoch - 1ms/step
# Epoch 71/200
# 84/84 - 0s - loss: 0.1252 - accuracy: 0.9616 - 100ms/epoch - 1ms/step
# Epoch 72/200
# 84/84 - 0s - loss: 0.1121 - accuracy: 0.9616 - 101ms/epoch - 1ms/step
# Epoch 73/200
# 84/84 - 0s - loss: 0.0843 - accuracy: 0.9784 - 100ms/epoch - 1ms/step
# Epoch 74/200
# 84/84 - 0s - loss: 0.1129 - accuracy: 0.9664 - 99ms/epoch - 1ms/step
# Epoch 75/200
# 84/84 - 0s - loss: 0.0809 - accuracy: 0.9736 - 100ms/epoch - 1ms/step
# Epoch 76/200
# 84/84 - 0s - loss: 0.0894 - accuracy: 0.9640 - 100ms/epoch - 1ms/step
# Epoch 77/200
# 84/84 - 0s - loss: 0.1284 - accuracy: 0.9568 - 101ms/epoch - 1ms/step
# Epoch 78/200
# 84/84 - 0s - loss: 0.1104 - accuracy: 0.9640 - 101ms/epoch - 1ms/step
# Epoch 79/200
# 84/84 - 0s - loss: 0.0918 - accuracy: 0.9712 - 101ms/epoch - 1ms/step
# Epoch 80/200
# 84/84 - 0s - loss: 0.0942 - accuracy: 0.9664 - 100ms/epoch - 1ms/step
# Epoch 81/200
# 84/84 - 0s - loss: 0.0896 - accuracy: 0.9640 - 101ms/epoch - 1ms/step
# Epoch 82/200
# 84/84 - 0s - loss: 0.0617 - accuracy: 0.9760 - 100ms/epoch - 1ms/step
# Epoch 83/200
# 84/84 - 0s - loss: 0.0793 - accuracy: 0.9832 - 100ms/epoch - 1ms/step
# Epoch 84/200
# 84/84 - 0s - loss: 0.0906 - accuracy: 0.9688 - 100ms/epoch - 1ms/step
# Epoch 85/200
# 84/84 - 0s - loss: 0.1010 - accuracy: 0.9664 - 102ms/epoch - 1ms/step
# Epoch 86/200
# 84/84 - 0s - loss: 0.1383 - accuracy: 0.9568 - 102ms/epoch - 1ms/step
# Epoch 87/200
# 84/84 - 0s - loss: 0.0811 - accuracy: 0.9736 - 100ms/epoch - 1ms/step
# Epoch 88/200
# 84/84 - 0s - loss: 0.0808 - accuracy: 0.9760 - 101ms/epoch - 1ms/step
# Epoch 89/200
# 84/84 - 0s - loss: 0.0782 - accuracy: 0.9760 - 102ms/epoch - 1ms/step
# Epoch 90/200
# 84/84 - 0s - loss: 0.1231 - accuracy: 0.9712 - 101ms/epoch - 1ms/step
# Epoch 91/200
# 84/84 - 0s - loss: 0.0782 - accuracy: 0.9760 - 101ms/epoch - 1ms/step
# Epoch 92/200
# 84/84 - 0s - loss: 0.0634 - accuracy: 0.9856 - 100ms/epoch - 1ms/step
# Epoch 93/200
# 84/84 - 0s - loss: 0.0511 - accuracy: 0.9856 - 100ms/epoch - 1ms/step
# Epoch 94/200
# 84/84 - 0s - loss: 0.1301 - accuracy: 0.9496 - 101ms/epoch - 1ms/step
# Epoch 95/200
# 84/84 - 0s - loss: 0.0941 - accuracy: 0.9664 - 101ms/epoch - 1ms/step
# Epoch 96/200
# 84/84 - 0s - loss: 0.0941 - accuracy: 0.9712 - 102ms/epoch - 1ms/step
# Epoch 97/200
# 84/84 - 0s - loss: 0.0806 - accuracy: 0.9736 - 101ms/epoch - 1ms/step
# Epoch 98/200
# 84/84 - 0s - loss: 0.0883 - accuracy: 0.9616 - 102ms/epoch - 1ms/step
# Epoch 99/200
# 84/84 - 0s - loss: 0.1061 - accuracy: 0.9664 - 102ms/epoch - 1ms/step
# Epoch 100/200
# 84/84 - 0s - loss: 0.0667 - accuracy: 0.9784 - 101ms/epoch - 1ms/step
# Epoch 101/200
# 84/84 - 0s - loss: 0.1288 - accuracy: 0.9520 - 100ms/epoch - 1ms/step
# Epoch 102/200
# 84/84 - 0s - loss: 0.1255 - accuracy: 0.9736 - 101ms/epoch - 1ms/step
# Epoch 103/200
# 84/84 - 0s - loss: 0.0961 - accuracy: 0.9640 - 100ms/epoch - 1ms/step
# Epoch 104/200
# 84/84 - 0s - loss: 0.0501 - accuracy: 0.9880 - 100ms/epoch - 1ms/step
# Epoch 105/200
# 84/84 - 0s - loss: 0.0620 - accuracy: 0.9832 - 102ms/epoch - 1ms/step
# Epoch 106/200
# 84/84 - 0s - loss: 0.0514 - accuracy: 0.9808 - 101ms/epoch - 1ms/step
# Epoch 107/200
# 84/84 - 0s - loss: 0.0769 - accuracy: 0.9712 - 101ms/epoch - 1ms/step
# Epoch 108/200
# 84/84 - 0s - loss: 0.1076 - accuracy: 0.9568 - 100ms/epoch - 1ms/step
# Epoch 109/200
# 84/84 - 0s - loss: 0.1021 - accuracy: 0.9616 - 101ms/epoch - 1ms/step
# Epoch 110/200
# 84/84 - 0s - loss: 0.0943 - accuracy: 0.9688 - 101ms/epoch - 1ms/step
# Epoch 111/200
# 84/84 - 0s - loss: 0.0844 - accuracy: 0.9736 - 101ms/epoch - 1ms/step
# Epoch 112/200
# 84/84 - 0s - loss: 0.1228 - accuracy: 0.9544 - 100ms/epoch - 1ms/step
# Epoch 113/200
# 84/84 - 0s - loss: 0.1077 - accuracy: 0.9688 - 101ms/epoch - 1ms/step
# Epoch 114/200
# 84/84 - 0s - loss: 0.1289 - accuracy: 0.9568 - 100ms/epoch - 1ms/step
# Epoch 115/200
# 84/84 - 0s - loss: 0.0765 - accuracy: 0.9712 - 101ms/epoch - 1ms/step
# Epoch 116/200
# 84/84 - 0s - loss: 0.0744 - accuracy: 0.9784 - 101ms/epoch - 1ms/step
# Epoch 117/200
# 84/84 - 0s - loss: 0.0731 - accuracy: 0.9784 - 101ms/epoch - 1ms/step
# Epoch 118/200
# 84/84 - 0s - loss: 0.0800 - accuracy: 0.9736 - 100ms/epoch - 1ms/step
# Epoch 119/200
# 84/84 - 0s - loss: 0.0964 - accuracy: 0.9664 - 99ms/epoch - 1ms/step
# Epoch 120/200
# 84/84 - 0s - loss: 0.1021 - accuracy: 0.9688 - 100ms/epoch - 1ms/step
# Epoch 121/200
# 84/84 - 0s - loss: 0.0551 - accuracy: 0.9808 - 99ms/epoch - 1ms/step
# Epoch 122/200
# 84/84 - 0s - loss: 0.0826 - accuracy: 0.9784 - 100ms/epoch - 1ms/step
# Epoch 123/200
# 84/84 - 0s - loss: 0.0725 - accuracy: 0.9784 - 100ms/epoch - 1ms/step
# Epoch 124/200
# 84/84 - 0s - loss: 0.0775 - accuracy: 0.9736 - 101ms/epoch - 1ms/step
# Epoch 125/200
# 84/84 - 0s - loss: 0.0755 - accuracy: 0.9736 - 100ms/epoch - 1ms/step
# Epoch 126/200
# 84/84 - 0s - loss: 0.0904 - accuracy: 0.9760 - 100ms/epoch - 1ms/step
# Epoch 127/200
# 84/84 - 0s - loss: 0.0993 - accuracy: 0.9640 - 104ms/epoch - 1ms/step
# Epoch 128/200
# 84/84 - 0s - loss: 0.1272 - accuracy: 0.9592 - 101ms/epoch - 1ms/step
# Epoch 129/200
# 84/84 - 0s - loss: 0.1132 - accuracy: 0.9640 - 102ms/epoch - 1ms/step
# Epoch 130/200
# 84/84 - 0s - loss: 0.0470 - accuracy: 0.9880 - 101ms/epoch - 1ms/step
# Epoch 131/200
# 84/84 - 0s - loss: 0.0922 - accuracy: 0.9712 - 100ms/epoch - 1ms/step
# Epoch 132/200
# 84/84 - 0s - loss: 0.0926 - accuracy: 0.9688 - 100ms/epoch - 1ms/step
# Epoch 133/200
# 84/84 - 0s - loss: 0.1060 - accuracy: 0.9712 - 99ms/epoch - 1ms/step
# Epoch 134/200
# 84/84 - 0s - loss: 0.0765 - accuracy: 0.9688 - 100ms/epoch - 1ms/step
# Epoch 135/200
# 84/84 - 0s - loss: 0.0952 - accuracy: 0.9664 - 100ms/epoch - 1ms/step
# Epoch 136/200
# 84/84 - 0s - loss: 0.0953 - accuracy: 0.9736 - 101ms/epoch - 1ms/step
# Epoch 137/200
# 84/84 - 0s - loss: 0.0514 - accuracy: 0.9856 - 100ms/epoch - 1ms/step
# Epoch 138/200
# 84/84 - 0s - loss: 0.0573 - accuracy: 0.9784 - 101ms/epoch - 1ms/step
# Epoch 139/200
# 84/84 - 0s - loss: 0.0574 - accuracy: 0.9856 - 100ms/epoch - 1ms/step
# Epoch 140/200
# 84/84 - 0s - loss: 0.0685 - accuracy: 0.9688 - 101ms/epoch - 1ms/step
# Epoch 141/200
# 84/84 - 0s - loss: 0.0736 - accuracy: 0.9832 - 100ms/epoch - 1ms/step
# Epoch 142/200
# 84/84 - 0s - loss: 0.0488 - accuracy: 0.9832 - 100ms/epoch - 1ms/step
# Epoch 143/200
# 84/84 - 0s - loss: 0.1038 - accuracy: 0.9688 - 100ms/epoch - 1ms/step
# Epoch 144/200
# 84/84 - 0s - loss: 0.0796 - accuracy: 0.9784 - 101ms/epoch - 1ms/step
# Epoch 145/200
# 84/84 - 0s - loss: 0.0938 - accuracy: 0.9664 - 101ms/epoch - 1ms/step
# Epoch 146/200
# 84/84 - 0s - loss: 0.1020 - accuracy: 0.9592 - 100ms/epoch - 1ms/step
# Epoch 147/200
# 84/84 - 0s - loss: 0.0582 - accuracy: 0.9784 - 100ms/epoch - 1ms/step
# Epoch 148/200
# 84/84 - 0s - loss: 0.0651 - accuracy: 0.9736 - 102ms/epoch - 1ms/step
# Epoch 149/200
# 84/84 - 0s - loss: 0.1044 - accuracy: 0.9496 - 100ms/epoch - 1ms/step
# Epoch 150/200
# 84/84 - 0s - loss: 0.0821 - accuracy: 0.9688 - 101ms/epoch - 1ms/step
# Epoch 151/200
# 84/84 - 0s - loss: 0.0723 - accuracy: 0.9760 - 101ms/epoch - 1ms/step
# Epoch 152/200
# 84/84 - 0s - loss: 0.0741 - accuracy: 0.9784 - 101ms/epoch - 1ms/step
# Epoch 153/200
# 84/84 - 0s - loss: 0.0982 - accuracy: 0.9688 - 101ms/epoch - 1ms/step
# Epoch 154/200
# 84/84 - 0s - loss: 0.0801 - accuracy: 0.9736 - 102ms/epoch - 1ms/step
# Epoch 155/200
# 84/84 - 0s - loss: 0.0796 - accuracy: 0.9784 - 104ms/epoch - 1ms/step
# Epoch 156/200
# 84/84 - 0s - loss: 0.0573 - accuracy: 0.9808 - 100ms/epoch - 1ms/step
# Epoch 157/200
# 84/84 - 0s - loss: 0.0497 - accuracy: 0.9856 - 99ms/epoch - 1ms/step
# Epoch 158/200
# 84/84 - 0s - loss: 0.0519 - accuracy: 0.9904 - 101ms/epoch - 1ms/step
# Epoch 159/200
# 84/84 - 0s - loss: 0.0507 - accuracy: 0.9832 - 101ms/epoch - 1ms/step
# Epoch 160/200
# 84/84 - 0s - loss: 0.0646 - accuracy: 0.9736 - 100ms/epoch - 1ms/step
# Epoch 161/200
# 84/84 - 0s - loss: 0.0809 - accuracy: 0.9664 - 99ms/epoch - 1ms/step
# Epoch 162/200
# 84/84 - 0s - loss: 0.0732 - accuracy: 0.9736 - 101ms/epoch - 1ms/step
# Epoch 163/200
# 84/84 - 0s - loss: 0.0465 - accuracy: 0.9880 - 101ms/epoch - 1ms/step
# Epoch 164/200
# 84/84 - 0s - loss: 0.0899 - accuracy: 0.9640 - 101ms/epoch - 1ms/step
# Epoch 165/200
# 84/84 - 0s - loss: 0.0731 - accuracy: 0.9712 - 101ms/epoch - 1ms/step
# Epoch 166/200
# 84/84 - 0s - loss: 0.0697 - accuracy: 0.9832 - 100ms/epoch - 1ms/step
# Epoch 167/200
# 84/84 - 0s - loss: 0.0589 - accuracy: 0.9760 - 100ms/epoch - 1ms/step
# Epoch 168/200
# 84/84 - 0s - loss: 0.0833 - accuracy: 0.9784 - 101ms/epoch - 1ms/step
# Epoch 169/200
# 84/84 - 0s - loss: 0.0748 - accuracy: 0.9712 - 100ms/epoch - 1ms/step
# Epoch 170/200
# 84/84 - 0s - loss: 0.1371 - accuracy: 0.9640 - 101ms/epoch - 1ms/step
# Epoch 171/200
# 84/84 - 0s - loss: 0.1026 - accuracy: 0.9712 - 147ms/epoch - 2ms/step
# Epoch 172/200
# 84/84 - 0s - loss: 0.0901 - accuracy: 0.9664 - 124ms/epoch - 1ms/step
# Epoch 173/200
# 84/84 - 0s - loss: 0.0690 - accuracy: 0.9784 - 117ms/epoch - 1ms/step
# Epoch 174/200
# 84/84 - 0s - loss: 0.0516 - accuracy: 0.9832 - 123ms/epoch - 1ms/step
# Epoch 175/200
# 84/84 - 0s - loss: 0.0823 - accuracy: 0.9688 - 173ms/epoch - 2ms/step
# Epoch 176/200
# 84/84 - 0s - loss: 0.1043 - accuracy: 0.9616 - 157ms/epoch - 2ms/step
# Epoch 177/200
# 84/84 - 0s - loss: 0.0886 - accuracy: 0.9760 - 106ms/epoch - 1ms/step
# Epoch 178/200
# 84/84 - 0s - loss: 0.0788 - accuracy: 0.9736 - 102ms/epoch - 1ms/step
# Epoch 179/200
# 84/84 - 0s - loss: 0.1106 - accuracy: 0.9664 - 101ms/epoch - 1ms/step
# Epoch 180/200
# 84/84 - 0s - loss: 0.0779 - accuracy: 0.9712 - 101ms/epoch - 1ms/step
# Epoch 181/200
# 84/84 - 0s - loss: 0.0789 - accuracy: 0.9760 - 101ms/epoch - 1ms/step
# Epoch 182/200
# 84/84 - 0s - loss: 0.1102 - accuracy: 0.9640 - 103ms/epoch - 1ms/step
# Epoch 183/200
# 84/84 - 0s - loss: 0.0759 - accuracy: 0.9736 - 102ms/epoch - 1ms/step
# Epoch 184/200
# 84/84 - 0s - loss: 0.0633 - accuracy: 0.9856 - 101ms/epoch - 1ms/step
# Epoch 185/200
# 84/84 - 0s - loss: 0.0877 - accuracy: 0.9688 - 101ms/epoch - 1ms/step
# Epoch 186/200
# 84/84 - 0s - loss: 0.0688 - accuracy: 0.9760 - 101ms/epoch - 1ms/step
# Epoch 187/200
# 84/84 - 0s - loss: 0.0710 - accuracy: 0.9760 - 100ms/epoch - 1ms/step
# Epoch 188/200
# 84/84 - 0s - loss: 0.0832 - accuracy: 0.9712 - 101ms/epoch - 1ms/step
# Epoch 189/200
# 84/84 - 0s - loss: 0.0739 - accuracy: 0.9712 - 100ms/epoch - 1ms/step
# Epoch 190/200
# 84/84 - 0s - loss: 0.1242 - accuracy: 0.9736 - 100ms/epoch - 1ms/step
# Epoch 191/200
# 84/84 - 0s - loss: 0.0682 - accuracy: 0.9760 - 100ms/epoch - 1ms/step
# Epoch 192/200
# 84/84 - 0s - loss: 0.0869 - accuracy: 0.9760 - 101ms/epoch - 1ms/step
# Epoch 193/200
# 84/84 - 0s - loss: 0.0779 - accuracy: 0.9688 - 99ms/epoch - 1ms/step
# Epoch 194/200
# 84/84 - 0s - loss: 0.0734 - accuracy: 0.9736 - 101ms/epoch - 1ms/step
# Epoch 195/200
# 84/84 - 0s - loss: 0.0735 - accuracy: 0.9760 - 102ms/epoch - 1ms/step
# Epoch 196/200
# 84/84 - 0s - loss: 0.0863 - accuracy: 0.9760 - 102ms/epoch - 1ms/step
# Epoch 197/200
# 84/84 - 0s - loss: 0.0776 - accuracy: 0.9784 - 101ms/epoch - 1ms/step
# Epoch 198/200
# 84/84 - 0s - loss: 0.0773 - accuracy: 0.9784 - 146ms/epoch - 2ms/step
# Epoch 199/200
# 84/84 - 0s - loss: 0.0702 - accuracy: 0.9736 - 160ms/epoch - 2ms/step
# Epoch 200/200
# 84/84 - 0s - loss: 0.0906 - accuracy: 0.9616 - 117ms/epoch - 1ms/step

# %%
words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))

# %%
model = load_model('chatbot_model.h5')

# %%
def clean_up_sentence (sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
    return sentence_words

def bag_of_words(sentence):
    sentence_words = clean_up_sentence (sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate (words):
            if word == w:
                bag[i] = 1
    return np.array (bag)

def predict_class (sentence):
    bow = bag_of_words(sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
    return return_list

def get_response(intents_list, intents_json):
    tag = intents_list[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

# %%
print("Go on ask! CollegeBot is ready at your service!!")
print("And if you want to stop Collegebot type 'exit' and hit enter!!")

while True:
    message = input("User: ")

    # Check if the user wants to quit
    if message.lower() == 'exit' or message.lower() == 'exit ':
        print("Goodbye!")
        break

    # Predict intent and get response
    ints = predict_class(message)
    res = get_response(ints, intents)
    
    # Print chatbot response
    print("College buddy:", res)
# Out:
# Go on ask! CollegeBot is ready at your service!!
# And if you want to stop Collegebot type 'exit' and hit enter!!
# User:  hi
# 1/1 [==============================] - 0s 145ms/step
# College buddy: Come back soon
# User: hod
# 1/1 [==============================] - 0s 30ms/step
# College buddy: HODs differ for each branch, please be more specific like: (HOD CS)
# User: hod comp
# 1/1 [==============================] - 0s 29ms/step
# College buddy: PROF. (DR.) SANDIP RAMRAO SHINDE is comp HOD who is available at Third of main building floor
# User: syllabus
# 1/1 [==============================] - 0s 28ms/step
# College buddy: To know about syllabus and timetable visit https://www.vit.edu/
# User: exit
# Goodbye!
